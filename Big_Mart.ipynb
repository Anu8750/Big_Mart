# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.float_format = "{:.2f}".format
pd.options.display.max_columns = None
sns.set_style("darkgrid")

# %% [markdown]
# # Import Dataset

# %%
df=pd.read_csv('Train-set.csv')
df
# Out:
#      ProductID  Weight FatContent  ProductVisibility            ProductType  \
# 0        FDA15    9.30    Low Fat               0.02                  Dairy
# 1        DRC01    5.92    Regular               0.02            Soft Drinks
# 2        FDN15   17.50    Low Fat               0.02                   Meat
# 3        FDX07   19.20    Regular               0.00  Fruits and Vegetables
# 4        NCD19    8.93    Low Fat               0.00              Household
# ...        ...     ...        ...                ...                    ...
# 8518     FDF22    6.87    Low Fat               0.06            Snack Foods
# 8519     FDS36    8.38    Regular               0.05           Baking Goods
# 8520     NCJ29   10.60    Low Fat               0.04     Health and Hygiene
# 8521     FDN46    7.21    Regular               0.15            Snack Foods
# 8522     DRG01   14.80    Low Fat               0.04            Soft Drinks
#
#         MRP OutletID  EstablishmentYear OutletSize LocationType  \
# 0    249.81   OUT049               1999     Medium       Tier 1
# 1     48.27   OUT018               2009     Medium       Tier 3
# 2    141.62   OUT049               1999     Medium       Tier 1
# 3    182.09   OUT010               1998        NaN       Tier 3
# 4     53.86   OUT013               1987       High       Tier 3
# ...     ...      ...                ...        ...          ...
# 8518 214.52   OUT013               1987       High       Tier 3
# 8519 108.16   OUT045               2002        NaN       Tier 2
# 8520  85.12   OUT035               2004      Small       Tier 2
# 8521 103.13   OUT018               2009     Medium       Tier 3
# 8522  75.47   OUT046               1997      Small       Tier 1
#
#              OutletType  OutletSales
# 0     Supermarket Type1      3735.14
# 1     Supermarket Type2       443.42
# 2     Supermarket Type1      2097.27
# 3         Grocery Store       732.38
# 4     Supermarket Type1       994.71
# ...                 ...          ...
# 8518  Supermarket Type1      2778.38
# 8519  Supermarket Type1       549.28
# 8520  Supermarket Type1      1193.11
# 8521  Supermarket Type2      1845.60
# 8522  Supermarket Type1       765.67
#
# [8523 rows x 12 columns]

# %% [markdown]
# # DATA UNDERSTANDING

# %%
df.head(10)
# Out:
#   ProductID  Weight FatContent  ProductVisibility            ProductType  \
# 0     FDA15    9.30    Low Fat               0.02                  Dairy
# 1     DRC01    5.92    Regular               0.02            Soft Drinks
# 2     FDN15   17.50    Low Fat               0.02                   Meat
# 3     FDX07   19.20    Regular               0.00  Fruits and Vegetables
# 4     NCD19    8.93    Low Fat               0.00              Household
# 5     FDP36   10.39    Regular               0.00           Baking Goods
# 6     FDO10   13.65    Regular               0.01            Snack Foods
# 7     FDP10     NaN    Low Fat               0.13            Snack Foods
# 8     FDH17   16.20    Regular               0.02           Frozen Foods
# 9     FDU28   19.20    Regular               0.09           Frozen Foods
#
#      MRP OutletID  EstablishmentYear OutletSize LocationType  \
# 0 249.81   OUT049               1999     Medium       Tier 1
# 1  48.27   OUT018               2009     Medium       Tier 3
# 2 141.62   OUT049               1999     Medium       Tier 1
# 3 182.09   OUT010               1998        NaN       Tier 3
# 4  53.86   OUT013               1987       High       Tier 3
# 5  51.40   OUT018               2009     Medium       Tier 3
# 6  57.66   OUT013               1987       High       Tier 3
# 7 107.76   OUT027               1985     Medium       Tier 3
# 8  96.97   OUT045               2002        NaN       Tier 2
# 9 187.82   OUT017               2007        NaN       Tier 2
#
#           OutletType  OutletSales
# 0  Supermarket Type1      3735.14
# 1  Supermarket Type2       443.42
# 2  Supermarket Type1      2097.27
# 3      Grocery Store       732.38
# 4  Supermarket Type1       994.71
# 5  Supermarket Type2       556.61
# 6  Supermarket Type1       343.55
# 7  Supermarket Type3      4022.76
# 8  Supermarket Type1      1076.60
# 9  Supermarket Type1      4710.53

# %% [markdown]
# # Find shape

# %%
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# # Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ProductID          8523 non-null   object
#  1   Weight             7060 non-null   float64
#  2   FatContent         8523 non-null   object
#  3   ProductVisibility  8523 non-null   float64
#  4   ProductType        8523 non-null   object
#  5   MRP                8523 non-null   float64
#  6   OutletID           8523 non-null   object
#  7   EstablishmentYear  8523 non-null   int64
#  8   OutletSize         6113 non-null   object
#  9   LocationType       8523 non-null   object
#  10  OutletType         8523 non-null   object
#  11  OutletSales        8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# # Data type

# %%
df.dtypes
# Out:
# ProductID             object
# Weight               float64
# FatContent            object
# ProductVisibility    float64
# ProductType           object
# MRP                  float64
# OutletID              object
# EstablishmentYear      int64
# OutletSize            object
# LocationType          object
# OutletType            object
# OutletSales          float64
# dtype: object

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['ProductID', 'FatContent', 'ProductType', 'OutletID', 'OutletSize',
#        'LocationType', 'OutletType'],
#       dtype='object')

# %%
df.select_dtypes(include='int').columns
# Out:
# Index(['EstablishmentYear'], dtype='object')

# %%
df.select_dtypes(include='float').columns
# Out:
# Index(['Weight', 'ProductVisibility', 'MRP', 'OutletSales'], dtype='object')

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#        Weight  ProductVisibility     MRP  EstablishmentYear  OutletSales
# count 7060.00            8523.00 8523.00            8523.00      8523.00
# mean    12.86               0.07  140.99            1997.83      2181.29
# std      4.64               0.05   62.28               8.37      1706.50
# min      4.55               0.00   31.29            1985.00        33.29
# 25%      8.77               0.03   93.83            1987.00       834.25
# 50%     12.60               0.05  143.01            1999.00      1794.33
# 75%     16.85               0.09  185.64            2004.00      3101.30
# max     21.35               0.33  266.89            2009.00     13086.96

# %%
df.describe(include='object')
# Out:
#        ProductID FatContent            ProductType OutletID OutletSize  \
# count       8523       8523                   8523     8523       6113
# unique      1559          5                     16       10          3
# top        FDW13    Low Fat  Fruits and Vegetables   OUT027     Medium
# freq          10       5089                   1232      935       2793
#
#        LocationType         OutletType
# count          8523               8523
# unique            3                  4
# top          Tier 3  Supermarket Type1
# freq           3350               5577

# %% [markdown]
# # Checking Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Checking Null Values

# %%
df.isna().sum()
# Out:
# ProductID               0
# Weight               1463
# FatContent              0
# ProductVisibility       0
# ProductType             0
# MRP                     0
# OutletID                0
# EstablishmentYear       0
# OutletSize           2410
# LocationType            0
# OutletType              0
# OutletSales             0
# dtype: int64

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# filling null values

# %%
missing_values=df.isna().sum()*100/len(df)
missing_values
# Out:
# ProductID            0.00
# Weight              17.17
# FatContent           0.00
# ProductVisibility    0.00
# ProductType          0.00
# MRP                  0.00
# OutletID             0.00
# EstablishmentYear    0.00
# OutletSize          28.28
# LocationType         0.00
# OutletType           0.00
# OutletSales          0.00
# dtype: float64

# %%
df['Weight'].fillna(df['Weight'].mode()[0],inplace=True)
df['OutletSize'].fillna(df['OutletSize'].mode()[0],inplace=True)
df.isna().sum()
# Out:
# ProductID            0
# Weight               0
# FatContent           0
# ProductVisibility    0
# ProductType          0
# MRP                  0
# OutletID             0
# EstablishmentYear    0
# OutletSize           0
# LocationType         0
# OutletType           0
# OutletSales          0
# dtype: int64

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# Finding Correlation

# %%
sns.heatmap(data=df.corr(numeric_only=True),fmt=".2g",annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Distribution Of ProductType By Location Type

# %%
plt.figure(figsize=(15,6))
ax = sns.countplot(data=df,x=df["ProductType"],order=df["ProductType"].value_counts().index,hue=df["LocationType"])
plt.xticks(rotation=90,weight ="bold")
plt.yticks(weight="bold")
plt.title("Distribution Of ProductType By Location Type",weight = "bold",pad=10,fontsize = 15)
plt.xlabel("Product Type",fontweight="bold",fontsize = 15)
plt.ylabel("")
for i in ax.containers:
    i.datavalues
    ax.bar_label(i,fontweight="bold",color="white",label_type="center",rotation=90)
plt.show()

# %% [markdown]
# # Distribution Of OutledID

# %%
plt.figure(figsize=(15,6))
sns.lineplot(data=df,x=df["OutletID"],y=df["MRP"])
plt.xticks(rotation=90)
plt.title("Distribution Of OutledID",pad=10,fontsize = 15,weight="bold")
plt.ylabel("MRP (Avg)",weight="bold",labelpad= 10,fontsize=15)
plt.xlabel("OutledID",weight="bold",labelpad=20,fontsize=15)
plt.xticks(weight="bold")
plt.yticks(weight="bold")
plt.show()

# %% [markdown]
# # Distribution Of MRP And OutletSales By MRP_RANGE

# %%
bins = np.arange(0,df["MRP"].max()+50,50)
Range = ["0-50","50-100","100-150","150-200","200-250","250-above"]
df["MRP_RANGE"] = pd.cut(df["MRP"],bins,labels=Range)

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(data=df,x=df["MRP"],y=df["OutletSales"],hue=df["MRP_RANGE"])
plt.xticks(weight="bold")
plt.yticks(weight="bold")
plt.title("Distribution Of MRP And OutletSales By MRP_RANGE",pad=10,fontsize = 15,weight="bold")
plt.ylabel("OutletSales",weight="bold",labelpad= 10,fontsize=15)
plt.xlabel("MRP",weight="bold",labelpad=20,fontsize=15)


plt.show()

# %% [markdown]
# # Distribution Of EstablishmentYear And OutletSales By OutletSize

# %%
plt.figure(figsize=(15,7))
sns.lineplot(data=df,x=df["EstablishmentYear"],y=df["OutletSales"],hue=df["OutletSize"])
plt.xticks(weight="bold")
plt.title("Distribution Of EstablishmentYear And OutletSales By OutletSize",pad=15,fontsize=15,weight="bold")
plt.yticks(weight="bold")
plt.xlabel("EstablishmentYear",labelpad=20,fontsize = 15,weight="bold")
plt.ylabel("OutletSales",labelpad=20,fontsize = 15,weight="bold")
plt.show()
